# %% [markdown]
# <a href="https://colab.research.google.com/github/Swapn2/deep_learning/blob/main/visualising_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications.vgg16 import VGG16
#Load the model
model = VGG16()

# %%
model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
from keras.utils import plot_model

plot_model(model)

# %%
for i in range(len(model.layers)):
	# check for convolutional layer
	if 'conv' not in model.layers[i].name:
		continue
	# get filter weights
	filters, biases = model.layers[i].get_weights()
	print("layer number",i,model.layers[i].name, filters.shape)
# Out:
# layer number 1 block1_conv1 (3, 3, 3, 64)
# layer number 2 block1_conv2 (3, 3, 64, 64)
# layer number 4 block2_conv1 (3, 3, 64, 128)
# layer number 5 block2_conv2 (3, 3, 128, 128)
# layer number 7 block3_conv1 (3, 3, 128, 256)
# layer number 8 block3_conv2 (3, 3, 256, 256)
# layer number 9 block3_conv3 (3, 3, 256, 256)
# layer number 11 block4_conv1 (3, 3, 256, 512)
# layer number 12 block4_conv2 (3, 3, 512, 512)
# layer number 13 block4_conv3 (3, 3, 512, 512)
# layer number 15 block5_conv1 (3, 3, 512, 512)
# layer number 16 block5_conv2 (3, 3, 512, 512)
# layer number 17 block5_conv3 (3, 3, 512, 512)

# %%
# retrieve weights from the second hidden layer
filters , bias = model.layers[1].get_weights()

# %%
# normalize filter values to 0-1 so we can visualize them
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)

# %%
from matplotlib import pyplot

n_filters =6
ix=1
fig = pyplot.figure(figsize=(15,10))
for i in range(n_filters):
    # get the filters
    f = filters[:,:,:,i]
    for j in range(3):
        # subplot for 6 filters and 3 channels
        pyplot.subplot(n_filters,3,ix)
        pyplot.imshow(f[:,:,j] ,cmap='gray')
        ix+=1
#plot the filters
pyplot.show()

# %%
from keras.models import Model
layer_output_model = Model(inputs=model.inputs , outputs=model.layers[1].output)

# %%
from keras.preprocessing.image import load_img, img_to_array
from numpy import expand_dims
from keras.applications.vgg16 import preprocess_input

image = load_img("/content/chair.jpg" , target_size=(224,224))

# convert the image to an array
image = img_to_array(image)
# expand dimensions so that it represents a single 'sample'
image = expand_dims(image, axis=0)

image = preprocess_input(image)

# %%
print(features.shape)
# Out:
# (1, 1000)

# %%
#calculating features_map
# Use the model that outputs the feature map of the second layer
features = layer_output_model.predict(image)

fig = pyplot.figure(figsize=(20,15))
# The shape of features is (1, 224, 224, 64) for the second layer
# Loop through the 64 feature maps (the last dimension)
num_feature_maps = features.shape[3]
# Determine grid size for subplots. Using 8x8 for 64 feature maps
grid_size = 8

for i in range(num_feature_maps):
    # subplot for grid_size x grid_size
    pyplot.subplot(grid_size, grid_size, i + 1) # +1 because subplot is 1-indexed
    pyplot.imshow(features[0, :, :, i] , cmap='gray') # Index i for the feature map

pyplot.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_46']
# Received: inputs=Tensor(shape=(1, 224, 224, 3))
#   warnings.warn(msg)

# %%
model2 = VGG16()

# %%
layer_index = [ 2, 5 , 9 , 13 , 17]
outputs = [model2.layers[i].output for i in layer_index]

model3 = Model( inputs= model2.inputs, outputs = outputs)

# %%
feature_map = model3.predict(image)

for i,fmap in zip(layer_index,feature_map):
    fig = pyplot.figure(figsize=(20,15))
    fig.suptitle("Layer_{}".format(i) , fontsize=20)
    for i in range(1,features.shape[3]+1):

        pyplot.subplot(8,8,i)
        pyplot.imshow(fmap[0,:,:,i-1] , cmap='gray')

pyplot.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_69']
# Received: inputs=Tensor(shape=(1, 224, 224, 3))
#   warnings.warn(msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 576ms/step
